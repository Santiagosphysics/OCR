# %%
import pytesseract
import numpy as np 
import cv2 

import matplotlib.pyplot as plt

# %%
img = cv2.imread('./resources/Images/test01.jpg')
plt.imshow(img)
plt.show()

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()

# %%
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

text = pytesseract.image_to_string(img)
print(text)

# %%
img = cv2.imread('./resources/Images/test02-02.jpg')
plt.imshow(img)
plt.show() 
text = pytesseract.image_to_string(img)
print(text)


rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()
text = pytesseract.image_to_string(rgb, lang='por')
print(text)
# Out:
# inteligéncia
# artificial e visao
# computacional
# inteligência
# artificial e visão
# computacional
